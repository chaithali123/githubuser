# %%
import re
class Restaurant:
    
    def __init__(self):

        self.food={}
        self.food_ID=len(self.food)+1
        self.user_details={}
        self.ordered_item=[]
        self.cost=[]


 
               
        
    def add_items(self):
        try:
            name=input("Enter the food name : ")
            quantity=float(input("Enter the quantity "))
            price=float(input("Enter the price in Rs only : "))
            discount=float(input("Enter the discount in  "))
            stock=float(input("Enter the available stock "))
            food_item={name:"name",quantity:"quantity",price:"price",discount:"discount",stock:"stock"}
            self.food_ID=len(self.food)+1
            self.food[self.food_ID]=food_item
            print("\n!! Food Item added successfully !!\n")
            print("Newly Added items :", self.food,"\n")
        except Exception as e:
            print("\n!! Something went wrong please try again !!\n")
            
            
            
    def view_items(self):
        print("List of Food Items : \n")    
        for x in self.food:
            
            print("foo id",x,"\n")
            for y in self.food[x]:
                print(y,"-" ,self.food[x][y])
            
        
    def edit_items(self):
      
            fid=int(input("enter foo_id"))
            for fid in self.food.keys():
                usr_choice= input("Enter item you want to update :name,quantity,price,discount,stock ")
                if usr_choice=="name":
                    self.food[fid]=input("food_name ")
                    
                elif usr_choice=="quantity":
                    self.food[fid]=float(input("quantity  "))
                     
                elif usr_choice=="price":
                    self.food[fid]=float(input("price "))
                     
                elif usr_choice=="discount":
                    self.food[fid]=float(input("discount "))
                    
                elif usr_choice=="stock":
                    self.food[fid]=float(input("stock "))
                       
                else:
                    print("not upated any values ")

            
    
            


    def delete_items(self):
        
            print("Enter the Food ID ")
            idd=int(input())
            if idd in self.food.keys():
                del self.food[x]
                print("successfully  deleted\n")
                print("remaning food in the ",self.food)
           
            
        
    def register(self):
        
            user_name=input("enter your full name  ")
            phone_no=int(input("enter your  phone number  "))
            email=input("enter your email id ")
            password=input("enter your password containing 8 letters followed by letter and number  ")
            n = 0
            while True:  
                if (len(password)<8):
                        n = -1
                        break
                elif not re.search("[a-z]", password):
                        n = -1
                elif not re.search("[0-9]", password):
                        n = -1
                else:
                    n = 0
                    print("Valid Password ")
                    break
            if n ==-1:
                print("Not a Valid Password")
                    
            address=input("Enter your place ")
            self.user_details={"User Name":user_name,"Phone No.":phone_no,"Email_ID":email,"Password":password,"Address":address}
            print("your account is created successfully ")
            
            for details in self.user_details:
                print(details, self.user_details[details])
        
        
    def login(self):
        
            while True:
                email=input("Enter Your Email ID : ")
                pasword=input("Enter Your Password : ")
                 
                if email==self.user_details["Email_ID"]:
                    if pasword==self.user_details["Password"]:
                            print(" Login successfully ")
                            break
                    else:
                         print(" Invalid Password ")
                else:
                    print(" Invalid Email ID ")
                 

 
       
    def place_order(self):
        
            menu_list=["1. Tandoori Chicken (4 pieces) [INR 240]", "2. Vegan Burger (1 Piece) [INR 320]","3.Truffle Cake 2(500gm) [INR 900]"]
            print("Menu Food List")
            price=[20,320,900]
#            ordered_item=[]
            
            count=0
            total=0
#             cost=[]
            order = input("can I take your order:y/n")
            if order=="n":
                 exit()
            else:
                print("thankyou")

            next=True
            while next==True:

                foodorder=input("please enter your item")
                if foodorder=="tandoori":
                    self.ordered_item.append(menu_list[0])
                    self.cost.append(price[0])
                    count=count+1
                    total=total+price[0]

                elif foodorder=="burger":
                    self.ordered_item.append(menu_list[1])
                    self.cost.append(price[1])
                    count=count+1
                    total=total+price[1]

                elif foodorder=="cake":
                    self.ordered_item.append(menu_list[2])
                    self.cost.append(price[2])
                    count=count+1
                    total=total+price[2]
                else:
                    print("sorry iteam is not in menu")

                x=input("finished ordering?: y/n")
                if x=="n":
                    next=False
                else:
                     next=True

            print(self.ordered_item)
            print(self.cost)
            print("the final coast is" + str(total))


  
                   
        
    def ordered_history(self):
        print("\nList of Previous ordered : ")
        for i in self.ordered_item:
            print(i)
            
    def update_details(self):
        
            while True:
                print(" update your profile details\n")
                print("1. Name\n2. Phone number\n3. Email ID\n4. Password\n5. Address\n6. Exit\n")
                x=input()
                if x=="1":
                    self.user_details["User_name"]=input("Enter your name : ")
                    print(" Updated Successfully ")
                    
                elif x=="2":
                    self.user_details["Phone No."]=int(input("Enter your  phone number : "))
                    print(" Updated Successfully ")
                   

                elif x=="3":
                    self.user_details["Email_id"]=input("Enter your updated email id : ")
                    print(" Updated Successfully ")
                  

                    
                elif x=="4":
                    self.user_details["Password"]=input("Enter your updated password : ")
                    print(" Updated Successfully ")
                    
                elif x=="5":
                    self.user_details["Address"]=input("Enter your adress ")
                    print("  Updated Successfully ")
              
                    
                elif x=="6":
                     exit() 
                else:
                    print(" Invalid Number Entered ")
                    
                 
                for i in self.user_details:
                        
                    print(i, ":",self.user_details[i])

                
            
               
try:
    def main():
        obj=Restaurant()
        print("  Welcome To  Restaurant  !!\n")
       
       
        
        while True:
            print("1. Admin\n2. User\n3. Exit\n")
            i=input()
            if i=="1":
                while True:
                    print("1. Add \n2. view Items\n3. edit Items \n4. delete items\n5. exit")
                    num=input()
                    if num=="1":
                        obj.add_items()
                    elif num=="2":
                        obj.view_items()
                        
                    elif num=="3":
                        obj.edit_items()
                    elif num=="4":
                        obj.delete_items()
                    elif num=="5":
                        break
                    else:
                        print("Invalid Number")
            elif i=="2":
                while True:
                    print("\nEnter the Below Options\n")
                    print("1. Register\n2. Login\n3. Exit\n")
                    num=input()
                    if num=="1":
                        obj.register()
                    elif num=="2":
                        obj.login()
                        while True:
                            print("\nEnter the Below Options\n")
                            print("1. Place New Order\n2. Check Order History\n3. Update Your Profile Details\n4. Exit")
                            x=input()
                            if x=="1":
                                obj.place_order()
                            elif x=="2":
                                obj.ordered_history()
                            elif x=="3":
                                obj.update_details()
                            elif x=="4":
                                break
                            else:
                                print("invalid Number")            
                    elif num=="3":
                        break
                    else:
                        print("\nInvalid Number ")        
            elif i=="3":
                break
            else:
                print("Invalid Number")

except Exception as e:
    print("something wrong")
                    
        
if __name__=='__main__':
    main()

print("thank you")
# Out:
#   Welcome To  Restaurant  !!
#
# 1. Admin
# 2. User
# 3. Exit
#
# 1
# 1. Add
# 2. view Items
# 3. edit Items
# 4. delete items
# 5. exit
# 1
# Enter the food name : burger
# Enter the quantity 1

# %% [markdown]
# #
